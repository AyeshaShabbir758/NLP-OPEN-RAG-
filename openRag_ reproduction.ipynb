# %% [markdown]
# This notebook reproduces the Adaptive Retrieval evaluation from the OPEN-RAG paper. Due to Colab hardware constraints, the evaluation script was executed on a 100-sample subset of the 2WikiMultihopQA dataset.

# %%
# !git clone https://github.com/ShayekhBinIslam/openrag.git
# %cd openrag
# !pip install -q transformers==4.42.4 peft accelerate bitsandbytes datasets sentencepiece jsonlines

# %%
# !python run_short_form_multihop.py --help

# %% [markdown]
# OPEN-RAG Model (Adaptive Retrieval)

# %%
# !python run_short_form_multihop.py \
  --model_name "shayekh/openrag_llama2_7b_8x135m" \
  --dataset "shayekh/openrag_bench" \
  --task "2wikimultihopqa" \
  --mode "adaptive_retrieval" \
  --threshold 0.5 \
  --metric "match" \
  --output_file "results_openrag.json" \
  --device "cuda" \
  --dtype "bfloat16"
